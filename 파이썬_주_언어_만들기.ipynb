# %% [markdown]
# <a href="https://colab.research.google.com/github/YuSeongShim/Python_colab/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%A3%BC_%EC%96%B8%EC%96%B4_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Day 0 - 개념 익히기

# %%
## 파이썬은 계산기 + 메모장

a = 3
b = 5
print(a + b)
# Out:
# 8

# %%
# 현재 a의 값을 꺼내서 + 1 계산 -> 그결과를 다시 a에 덮어쓴다

a = a + 1

# %%
print(4)
# Out:
# 4

# %%
a = 3
a = a + 1
print(a)
# Out:
# 4

# %% [markdown]
# ## 🧠 개념 확정: input의 정체

# %%
n = input() # 문자열로 들어옴

# %%
print( n + 1) # 오류가 날 수 밖에 없음

# %%
n = int(input())

print(n + 1)
# Out:
# 3
# 4

# %% [markdown]
# ## 🚀 다음 단계: 반복의 세계 (for)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
total = 0

for i in range(3):
    n = int(input())
    total = total + n

print(total)
# Out:
# 3
# 2
# 1
# 6

# %%
n = int(input())
total = 0

for i in range(n):
    n = int(input())
    total = total + n

print(total)
# Out:
# 3
# 2
# 1
# 2
# 5
