# %% [markdown]
# <a href="https://colab.research.google.com/github/YuSeongShim/Python_colab/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%A3%BC_%EC%96%B8%EC%96%B4_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Day 1 - “파이썬이 뭐고, 코드는 어떻게 흘러가는가”

# %% [markdown]
# ## 파이썬은 어떤 언어?

# %%
# 파이썬 - 사람이 읽기 쉬운 언어
# 공학에서 쓰는 이유
# 빠른 프로토타이핑
# 알고리즘 연습
# AI / 자동화 / HCI 연구까지 가능

# %% [markdown]
# ## 첫 코드 : print

# %%
# 위 아래로 순서대로 실행
# print() = 화면에 보여주는 역할

print("Hello, Python")
print(10)
print(10 + 3)
# Out:
# Hello, Python
# 10
# 13

# %% [markdown]
# ## 변수 = 값에 이름 붙이기

# %%
# =은 같다 x
# =은 저장한다 o

a = 10
b = 3
print(a+b)
# Out:
# 13

# %% [markdown]
# ## 입력받기 - input

# %%
# input()으로 받는 건 무조건 문자열(str)

a = input()
print(a)
# Out:
# as
# as

# %%
# 이렇게 씀
# int가 필요한 이유 - 문자열을 더하면 붙고, 숫자는 계산됨

a = int(input())
b = int(input())
print(a + b)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 핵심 문장 - 이해하기!!

# %%
# 파이썬 프로그래밍 = 입력 -> 처리 -> 출력
# 이 구조는 알고리즘, 임베디드, UI 이벤트 다 동일

# %% [markdown]
# ## 실전 미션

# %%
##  백준 1000번(A+B)

a, b = map(int, input().split())

print(a+b)
# Out:
# 1 2
# 3

# %% [markdown]
# ## Python Day 2 - "조건문(IF")

# %% [markdown]
# ## 왜 조건문이 필요할까?

# %%
# 온도가 30도 이상 -> 에어컨 on
# 아니면 -> off
# 이걸 코드로 판단하게 하는게 if

# %% [markdown]
# ## if 기본 구조(형태 익히기)

# %%
if 조건:
    실행문

# %%
# 들여쓰기 = 블록
# 파이썬은 {} 대신 공백으로 구분

x = 10

if x > 0:
    print("양수")

# %% [markdown]
# ## 비교 연산자 정리

# %%
# | 기호   | 의미  |
# | ---- | --- |
# | `>`  | 크다  |
# | `<`  | 작다  |
# | `==` | 같다  |
# | `!=` | 다르다 |
# | `>=` | 이상  |
# | `<=` | 이하  |

# %% [markdown]
# ## if / elif / else 구조

# %%
# 경우의 수를 나눈다는 사고가 중요함

if a > b:
    print("a가 크다")

elif a < b:
    print("b가 크다")

else:
    print("같다")

# %% [markdown]
# ## 실전연결

# %%
# 백준 1330번
# 두 정수 A, B | A와 B의 대소관계를 출력

a, b = map(int, input().split())

if a > b:
    print(">")

elif a < b:
    print("<")

else:
    print("==")

# %% [markdown]
# ## Day 3 - 반복문 for = 알고리즘 체력

# %% [markdown]
# ## 왜 반복문이 필요할까?

# %%
## 👉 전공 연결
## 센서 값 N번 읽기
## 데이터 샘플 처리
## 배열 순회

# %% [markdown]
# ## for문 기본 구조

# %%
## 여기서 중요한 거 ⚠️
## range(5) → 0부터 4까지
## 반복 변수 i 는 임시 변수

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## range() 완전 정복

# %%
# # 형태               | 의미        |
##  | ---------------- | --------- |
## | `range(n)`       | 0 ~ n-1   |
## | `range(a, b)`    | a ~ b-1   |
## | `range(a, b, c)` | a부터 c씩 증가 |

# %%
## 예시

range(1, 10)   # 1 ~ 9
range(2, 11, 2) # 짝수
# Out:
# range(2, 11, 2)

# %% [markdown]
# ## for + print 조합 예시

# %%
## 👉 이걸로 뭐 가능?
## 합 구하기
## 개수 세기
## 조건 검사

for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 실전연결

# %%
## 백준 2739
## N을 입력받은 뒤, 구구단 N단을 출력하는 프로그램을 작성하시오. 출력 형식에 맞춰서 출력하면 된다.
