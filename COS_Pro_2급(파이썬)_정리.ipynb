# %% [markdown]
# <a href="https://colab.research.google.com/github/YuSeongShim/Python_colab/blob/main/COS_Pro_2%EA%B8%89(%ED%8C%8C%EC%9D%B4%EC%8D%AC)_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3. Hello, world!로 시작하기

# %%
print('Hello, world!') # 문자열 출력
# Out:
# Hello, world!

# %%
# 연습문제 : 문자열 출력하기

print('Hello, world!')
print('12345x7890')
# Out:
# Hello, world!
# 12345x7890

# %% [markdown]
# # Unit 4. 기본 문법 알아보기

# %% [markdown]
# ## 4.1 세미콜론

# %%
## 많은 프로그래밍 언어들은 구문이 끝날 때 ; (세미콜론)을 붙여야 함, 하지만 파이썬은 x

print('Hello, world!')
print('Hello'); print('1234')
# Out:
# Hello, world!
# Hello
# 1234

# %% [markdown]
# ## 4.2 주석

# %%
## 파이썬에서 사람만 알아볼 수 있도록 작성하는 부분 -> 주석

#print('Hello, world')

a = 1 + 2 # 더하기
print('Hello, world!') # printf('1234567890')

#print('Hello, world!')
#print('1234567890')

# 더하기
# a = 1 + 2
# print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ## 4.3 들여쓰기

# %%
# 코드를 읽기 쉽도록 일정한 간격을 띄워서 작성하는 방법

if a == 10:
    print('10입니다.') # 들여쓰기 문법 에러

# %%
# 파이썬

if a == 10:
    print('10입니다.')
# 들여쓰기 공백 4칸

# %% [markdown]
# ## 4.4 코드 블록

# %%
# 특정한 동작을 위해서 코드가 모여 있는 상태
# , 같은 블록은 들여쓰기 칸 수가 같아야 하고, 공백과 탭 문자를 섞어 쓰면 안 됨


if a == 10:
    print('10')
    print('입니다.')

# %% [markdown]
# # Unit 5. 숫자 계산하기

# %%
1 + 1
# Out:
# 2

# %%
1 - 2
# Out:
# -1

# %%
2 * 2
# Out:
# 4

# %%
5  / 2
# Out:
# 2.5

# %%
## 정수 나눗셈의 결과를 정수로 만들고 싶다면?

int(5 / 2)
# Out:
# 2

# %% [markdown]
# ## 5.2 실수 계산하기

# %%
3.5 + 2.1
# Out:
# 5.6

# %%
4.3 - 2.7
# Out:
# 1.5999999999999996

# %%
1.5 * 3.1
# Out:
# 4.65

# %%
5.5 / 3.1
# Out:
# 1.7741935483870968

# %%
4.2 + 5
# Out:
# 9.2

# %%
# 계산 결과를 실수로 만들고 싶다면?

float(1 + 2)
# Out:
# 3.0

# %%
# 복소수

1.2+1.3j
complex(1.2, 1.3)
# Out:
# (1.2+1.3j)

# %% [markdown]
# ## 5.5 연습문제: 스킬 공격력 구하기

# %%
print(225 + (0.6 * 102))
# Out:
# 286.2

# %% [markdown]
# # Unit 6. 변수 사용하기

# %% [markdown]
# ## 6.1 변수 만들기

# %%
x = 10
x
# Out:
# 10

# %%
x = 10
print(x) # print로 변수의 값 출력
# Out:
# 10

# %% [markdown]
# ## 6.2 빈 변수 만들기

# %%
x = None
x

# %%
# 보총 빈 값을 출력할때는 None 이라는 값을 사용함

print(x)
# Out:
# None

# %% [markdown]
# ## 6.3 변수의 값 변경하기

# %%
x = 10  # 변수 만들기
x
# Out:
# 10

# %%
x = 20  # 변수의 값을 20으로 변경
x
# Out:
# 20

# %%
x = 30 + 40 # 변수의 값을 30 + 40의 결과로 변경
x
# Out:
# 70

# %% [markdown]
# ## 6. 4 변수 여러 개를 한 번에 만들기

# %%
x , y, z = 10, 20, 30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
x = y = z = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
z
# Out:
# 10

# %% [markdown]
# ## 6.5 변수에 변수 할당하기

# %%
# 변수에는 값 뿐만이 아니라 다른 변수도 할당 할 수 있음

x = 10
y = x
y
# Out:
# 10

# %%
a, b = 10, 20
x, y = a, b

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
x = 10
y = 20
x, y = y, x

# %%
x
# Out:
# 20

# %%
y
# Out:
# 10

# %%
# 변수 삭제하기

x = 10
del x

# %% [markdown]
# ## 6.7 연습문제: 변수 만들기

# %%
a = b = 10
c, d = 20, None

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 10
# 20
# None
