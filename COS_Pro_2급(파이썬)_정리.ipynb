# %% [markdown]
# <a href="https://colab.research.google.com/github/YuSeongShim/Python_colab/blob/main/COS_Pro_2%EA%B8%89(%ED%8C%8C%EC%9D%B4%EC%8D%AC)_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3. Hello, world!로 시작하기

# %%
print('Hello, world!') # 문자열 출력
# Out:
# Hello, world!

# %%
# 연습문제 : 문자열 출력하기

print('Hello, world!')
print('12345x7890')
# Out:
# Hello, world!
# 12345x7890

# %% [markdown]
# # Unit 4. 기본 문법 알아보기

# %% [markdown]
# ## 4.1 세미콜론

# %%
## 많은 프로그래밍 언어들은 구문이 끝날 때 ; (세미콜론)을 붙여야 함, 하지만 파이썬은 x

print('Hello, world!')
print('Hello'); print('1234')
# Out:
# Hello, world!
# Hello
# 1234

# %% [markdown]
# ## 4.2 주석

# %%
## 파이썬에서 사람만 알아볼 수 있도록 작성하는 부분 -> 주석

#print('Hello, world')

a = 1 + 2 # 더하기
print('Hello, world!') # printf('1234567890')

#print('Hello, world!')
#print('1234567890')

# 더하기
# a = 1 + 2
# print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ## 4.3 들여쓰기

# %%
# 코드를 읽기 쉽도록 일정한 간격을 띄워서 작성하는 방법

if a == 10:
    print('10입니다.') # 들여쓰기 문법 에러

# %%
# 파이썬

if a == 10:
    print('10입니다.')
# 들여쓰기 공백 4칸

# %% [markdown]
# ## 4.4 코드 블록

# %%
# 특정한 동작을 위해서 코드가 모여 있는 상태
# , 같은 블록은 들여쓰기 칸 수가 같아야 하고, 공백과 탭 문자를 섞어 쓰면 안 됨


if a == 10:
    print('10')
    print('입니다.')

# %% [markdown]
# # Unit 5. 숫자 계산하기

# %%
1 + 1
# Out:
# 2

# %%
1 - 2
# Out:
# -1

# %%
2 * 2
# Out:
# 4

# %%
5  / 2
# Out:
# 2.5

# %%
## 정수 나눗셈의 결과를 정수로 만들고 싶다면?

int(5 / 2)
# Out:
# 2

# %% [markdown]
# ## 5.2 실수 계산하기

# %%
3.5 + 2.1
# Out:
# 5.6

# %%
4.3 - 2.7
# Out:
# 1.5999999999999996

# %%
1.5 * 3.1
# Out:
# 4.65

# %%
5.5 / 3.1
# Out:
# 1.7741935483870968

# %%
4.2 + 5
# Out:
# 9.2

# %%
# 계산 결과를 실수로 만들고 싶다면?

float(1 + 2)
# Out:
# 3.0

# %%
# 복소수

1.2+1.3j
complex(1.2, 1.3)
# Out:
# (1.2+1.3j)

# %% [markdown]
# ## 5.5 연습문제: 스킬 공격력 구하기

# %%
print(225 + (0.6 * 102))
# Out:
# 286.2

# %% [markdown]
# # Unit 6. 변수 사용하기

# %% [markdown]
# ## 6.1 변수 만들기

# %%
x = 10
x
# Out:
# 10

# %%
x = 10
print(x) # print로 변수의 값 출력
# Out:
# 10

# %% [markdown]
# ## 6.2 빈 변수 만들기

# %%
x = None
x

# %%
# 보총 빈 값을 출력할때는 None 이라는 값을 사용함

print(x)
# Out:
# None

# %% [markdown]
# ## 6.3 변수의 값 변경하기

# %%
x = 10  # 변수 만들기
x
# Out:
# 10

# %%
x = 20  # 변수의 값을 20으로 변경
x
# Out:
# 20

# %%
x = 30 + 40 # 변수의 값을 30 + 40의 결과로 변경
x
# Out:
# 70

# %% [markdown]
# ## 6. 4 변수 여러 개를 한 번에 만들기

# %%
x , y, z = 10, 20, 30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
x = y = z = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
z
# Out:
# 10

# %% [markdown]
# ## 6.5 변수에 변수 할당하기

# %%
# 변수에는 값 뿐만이 아니라 다른 변수도 할당 할 수 있음

x = 10
y = x
y
# Out:
# 10

# %%
a, b = 10, 20
x, y = a, b

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
x = 10
y = 20
x, y = y, x

# %%
x
# Out:
# 20

# %%
y
# Out:
# 10

# %%
# 변수 삭제하기

x = 10
del x

# %% [markdown]
# ## 6.7 연습문제: 변수 만들기

# %%
a = b = 10
c, d = 20, None

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 10
# 20
# None

# %% [markdown]
# # Unit 7. 문자열 사용하기

# %% [markdown]
# ## 7.1 문자열을 변수에 저장하기

# %%
# 변수에 문자열을 할당하면 문자열이 저장됨

hello1 = 'Hello, world!'
print(hello1)
# Out:
# Hello, world!

# %%
# 문자열을 사용할 때는 주로 작은 따옴표를 사용함

hello2 = "Hello, world!"
print(hello2)
# Out:
# Hello, world!

# %%
# 참고로 한글 문자열도 사용할 수 있음

hello3 = '안녕하세요'
print(hello3)
# Out:
# 안녕하세요

# %%
# 여러 줄로 된 문자열을 변수에 저장 함

hello = '''Hello, world!
안녕허세요.
Python입니다.'''
print(hello)
# Out:
# Hello, world!
# 안녕허세요.
# Python입니다.

# %%
single_quote = '''"안녕하세요."
'파이썬'입니다.'''

double_quote1 = """"Hello"
'Python'"""

double_quote2 = """Hello, 'Python'"""    # 한 줄로 작성

print(single_quote)
print(double_quote1)
print(double_quote2)
# Out:
# "안녕하세요."
# '파이썬'입니다.
# "Hello"
# 'Python'
# Hello, 'Python'

# %% [markdown]
# ## 7.2 문자열의 길이 구하기

# %%
hello = "Hello, world!"
len(hello)
# Out:
# 13

# %%
hello = '안녕하세요'
len(hello)
# Out:
# 5

# %% [markdown]
# ## 7.3 문자열을 연결하고 반복하기

# %%
# 문자열 연결하기
hello = 'Hello, '
world = 'world!'
hello + world
# Out:
# 'Hello, world!'

# %%
# 문자열 반복
hello * 3
# Out:
# 'Hello, Hello, Hello, '

# %%
'Hello, ' + 'world!'
# Out:
# 'Hello, Hello, Hello, '

# %%
'Hello, ' * 3
# Out:
# 'Hello, Hello, Hello, '

# %%
# 문자열 + str(정수, 실수)

'Hello, ' + str(10)
# Out:
# 'Hello, 10'

# %%
'Hello, ' + str(1.5)
# Out:
# 'Hello, 1.5'

# %% [markdown]
# ## 7.5 연습문제: 문자열의 길이 출력하기

# %%
s = 'Hello, Python'

print('s의 길이는 ' + str(len(s)) + '입니다.')
# Out:
# s의 길이는 13입니다.

# %% [markdown]
# # Unit 8. 입력 값을 변수에 저장하기

# %% [markdown]
# ## 8.1 문자열 입력받기

# %%
input()
# Out:
# 안녕하세요
# '안녕하세요'

# %%
input('문자열을 입력하세요: ')
# Out:
# 문자열을 입력하세요: Hello, world!
# 'Hello, world!'

# %%
s = input('문자열을 입력하세요: ')

print(s)
# Out:
# 문자열을 입력하세요: Hello, world
# Hello, world

# %% [markdown]
# ## 8.2 숫자 입력받기

# %%
a = input('첫 번째 숫자를 입력하세요: ')
b = input('두 번째 숫자를 입력하세요: ')

print(a + b)
# Out:
# 첫 번째 숫자를 입력하세요: 1
# 두 번째 숫자를 입력하세요: 2
# 12

# %%
## 숫자로 문자열 입력받기

a = int(input("첫 번째 숫자를 입력하세요: "))
b = int(input("두 번째 숫자를 입력하세요: "))

print(a + b)
# Out:
# 첫 번째 숫자를 입력하세요: 1
# 두 번째 숫자를 입력하세요: 2
# 3

# %%
## 실수로 숫자 입력받기

a = float(input('첫 번째 숫자를 입력하세요: '))
b = float(input('두 번째 숫자를 입력하세요: '))

print(a + b)
# Out:
# 첫 번째 숫자를 입력하세요: 1
# 두 번째 숫자를 입력하세요: 3
# 4.0

# %% [markdown]
# ## 8.3 한 번에 값 두 개 입력받기

# %%
a, b = input('문자열 두 개를 입력하세요: ').split()

a = int(a)
b = int(b)

print(a + b)
# Out:
# 문자열 두 개를 입력하세요: 30 40
# 70

# %%
print(int(a) + int(b))
# Out:
# 70

# %%
a, b = map(int, input('숫자 두 개를 입력하세요: ').split())

print(a + b)
# Out:
# 숫자 두 개를 입력하세요: 4 5
# 9

# %%
a, b = map(int, input('숫자 두 개를 입력하세요: ').split(','))

print(a + b)
# Out:
# 숫자 두 개를 입력하세요: 30,40
# 70

# %% [markdown]
# ## 8.5 연습문제 : 한 번에 정수 세 개 입력받기

# %%
a, b, c = map(int, input().split())

print(a + b + c)
# Out:
# 10 20 30
# 60

# %% [markdown]
# # Unit 9. 출력 방법 알아보기

# %% [markdown]
# ## 9.1 값을 여러 개 출력하기

# %%
# print에는 변수나 값 여러 개를 ,(콤마)로 구분하여 넣을 수 있음

print(1, 2, 3)
# Out:
# 1 2 3

# %%
print('Hello', 'Python')
# Out:
# Hello Python

# %%
# 값 사이에 공백이 아닌 다른 문자를 넣고 싶다면

print(1, 2, 3, sep=', ') # sep에 콤마와 공백을 지정
# Out:
# 1, 2, 3

# %%
print(4,5,6, sep=',')
# Out:
# 4,5,6

# %%
print('Hello', 'Python', sep='')
# Out:
# HelloPython

# %%
print(1920, 1080, sep='x')
# Out:
# 1920x1080

# %% [markdown]
# ## 9.2 줄바꿈 활용하기

# %%
print(1, 2, 3)
# Out:
# 1 2 3

# %%
print(1,2,3, sep='\n')
# Out:
# 1
# 2
# 3

# %%
print('1\n2\n3')
# Out:
# 1
# 2
# 3

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
# 한 줄에 여러 개의 값을 출력할 수 있다면

print(1, end='')
print(2, end='')
print(3)
# Out:
# 123

# %%
print(1, end=' ')
print(2, end=' ')
print(3)
# Out:
# 1 2 3

# %% [markdown]
# ## 9.4 연습문제: 날짜와 시간 출력하기

# %%
year = 2000
month = 10
day = 27
hour = 11
minute = 43
second = 59

print(year, month, day, sep='/', end=' ' )
print(hour, minute, second, sep=':')
# Out:
# 2000/10/27 11:43:59

# %% [markdown]
# # Unit 10. 산술 연산자 알아보기

# %%
10 + 20
# Out:
# 30

# %%
10 - 20
# Out:
# -10

# %%
10 * 20
# Out:
# 200

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
int(5 / 2)
# Out:
# 2

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
2 ** 10
# Out:
# 1024

# %%
# 몫과 나머지를 함께 구하기

divmod(5, 2)
# Out:
# (2, 1)

# %%
quotient, remainder = divmod(5, 2)
print(quotient, remainder)
# Out:
# 2 1

# %%
# 부호를 붙여야 하는 경우
x = -10

# %%
+x
# Out:
# -10

# %%
-x
# Out:
# 10

# %% [markdown]
# ## 10.2 산술 연산 후 할당 연산자 사용하기

# %%
a = 10
b = 20
a += b
a
# Out:
# 30

# %%
a += b # a와 b를 더한 후 결과를 다시 a에 저장
a = a + b

# %%
# 나머지 연산 할당

a = 5
b = 2
a %= b
a
# Out:
# 1

# %% [markdown]
# ## 10.3 괄호 사용하기

# %%
35 + 1 * 2
# Out:
# 37

# %%
# 곱셈보다 덧셈을 먼저 계산하고 싶다면

(35 + 1) * 2
# Out:
# 72

# %% [markdown]
# ## 10.5 연습문제: 점수 평균 구하기

# %%
korean = 94
english = 91
mathematics = 89
science = 83

average = ((korean + english + mathematics + science) / 4)
print(average)
# Out:
# 89.25

# %% [markdown]
# # Unit 11. 불과 비교, 논리 연산자 알아보기

# %% [markdown]
# ## 11.1 불과 비교 연산자 사용하기

# %%
# 불은 True, False로 표현하며 1, 3.6. 'Python' 처럼 값의 일종

True
# Out:
# True

# %%
False
# Out:
# False

# %%
3 > 1
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 != 5
# Out:
# True

# %%
'Python' == 'Python'
# Out:
# True

# %%
'Python' != 'python'
# Out:
# True

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %%
1 == 1.0
# Out:
# True

# %%
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipython-input-3336455986.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1.0
# False

# %% [markdown]
# ## 11.2 논리 연산자 사용하기

# %%
# a and b
# 두 값이 모두 True라야 True임

True and True
True and False
False and True
False and False
# Out:
# False

# %%
# a or b
# 두 값 중 하나라도 True이면 True
True or True
True or False
False or True
False or False
# Out:
# False

# %%
# not
# 논리값을 뒤집음

10 == 10 and 10 != 5
10 > 5 or 10 < 3
not 10 > 5
# Out:
# False

# %% [markdown]
# ## 11.4 연습문제 : 합격 여부 출력하기

# %%
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >= 50 and english >= 50 and  mathematics >= 50 and science >= 50)
# Out:
# False

# %% [markdown]
# # Unit 12.  if 조건문으로 특정 조건일 때 코드 실행하기

# %% [markdown]
# ## 12.1 if 조건문 사용하기

# %%
if 조건식:
      코드

# %%
x = 10
if x == 10:
    print('10입니다.')
# Out:
# 10입니다.

# %%
x = 10
if x == 10:
    pass

# %% [markdown]
# ## 12.2 if 조건문과 들여쓰기

# %%
x = 10

if x == 10:
    print('x에 들어있는 숫자는')
    print('10입니다')
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
x = 10

if x == 10:
      print('x에 들어있는 숫자는'
print('10입니다.')
# Out:
#   File "/tmp/ipython-input-4188596956.py", line 4
#     print('x에 들어있는 숫자는'
#          ^
# SyntaxError: '(' was never closed

# %%
x = 5

if x == 10:
    print('x에 들어있는 숫자는')
print('10입니다.')
# Out:
# 10입니다.

# %% [markdown]
# ## 12.3 중첩 if 조건문 사용하기

# %%
x = 15

if x >= 10:
    print('10 이상입니다.')

    if x == 15:
          print('15입니다.')

    if x == 20:
          print('20입니다.')
# Out:
# 10 이상입니다.
# 15입니다.

# %% [markdown]
# ## 12.4 사용자가 입력한 값에 if 조건문 사용하기

# %%
x = int(input())

if x == 10:
    print('10입니다.')

if x == 20:
    print('20입니다.')
# Out:
# 20
# 20입니다.

# %% [markdown]
# ## 12.6 연습문제

# %%
x = 5

if x != 10:
    print('ok')
# Out:
# ok
