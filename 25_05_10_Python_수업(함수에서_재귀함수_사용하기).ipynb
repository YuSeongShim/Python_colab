# %% [markdown]
# <a href="https://colab.research.google.com/github/YuSeongShim/Python_colab/blob/main/25_05_10_Python_%EC%88%98%EC%97%85(%ED%95%A8%EC%88%98%EC%97%90%EC%84%9C_%EC%9E%AC%EA%B7%80%ED%95%A8%EC%88%98_%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 함수에서 재귀호출 사용하기

# %%
## 함수 안에서 함수 자기자신을 호출하는 방식 -> 재귀호출(recursive)

# %% [markdown]
# ## 재귀호출 사용하기

# %%
## 파이썬에서는 최대 재귀 깊이가 1000으로 정해져 있어서 이렇나 현상이 나타남

def hello():
    print('Hello, world!')
    hello()

hello()
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# ...

# %% [markdown]
# ## 재귀호출에 종료 조건 만들기

# %%
def hello(count):
    if count == 0: # 종료 조건을 만듦. count가 0이면 다시 hello 함수를 호출하지 않고 끝냄
      return

    print('Hello, world!', count)

    count -= 1 # count를 1 감소
    hello(count) # 다시 hello에 넣음

hello(5) # hello 함수 호출
# Out:
# Hello, world! 5
# Hello, world! 4
# Hello, world! 3
# Hello, world! 2
# Hello, world! 1

# %% [markdown]
# ## 재귀호출로 팩토리얼 구하기

# %%
# 팩토리얼은 1부터 n까지 양의 정수를 차례대로 곱한 값
# ex) 5! = 5*4*3*2*1

def factorial(n):
    if n == 1: # n이 1일 때
        return 1 # 1을 반환하고 재귀호출을 끝냄
    return n * factorial(n - 1) # n과 factorial 함수에 n - 1을 넣어서 반환된 값을 곱함

print(factorial(5))
# Out:
# 120

# %%
# 여기서는 n부터 역순으로 1씩 감소하면서 재귀호출을 하고 n이 1이 되었을 때 재귀호출 중단

def factorial(n):
    if n == 1:  # n이 1일 때
        return 1 # 1을 반환하고 재귀호출을 끝냄

# %%
# 핵심!! -> 반환값 부분
# 계산 결과가 즉시 구해지는 것 x

    return n * factorial(n - 1) # n과 factorial 함수에 n-1을 넣어서 반환된 값을 곱함

# %% [markdown]
# ## 퀴즈

# %%
# 다음 중 재귀호출에 대한 설명으로 잘못된 것을 고르세요
# 답: a, c

# %%
# 다음 증 팩토리얼을 표기하는 방법으로 올바른 것은?
# 답: a

# %%
# 4 팩토리얼의 결괏값을 구하라
# 답 : 24

# %% [markdown]
# ## 연습문제: 재귀호출로 회문 판별하기

# %%
def is_palindrome(word):
  if len(word) < 2:
      return True
  if word[0] != word[-1]:
      return False
  return is_palindrome(word[1:-1])

print(is_palindrome('hello'))
print(is_palindrome('level'))

# %% [markdown]
# ## 심사문제: 재귀함수로 피보나치 수 구하기

# %%
def fib(n):
  if n == 1 or n == 2:
    return 1 # 실행은 되었으나 추가적으로 알아야 할 때 사용함!!
  return fib(n-2) + fib(n-1)

n = int(input())
print(fib(n))
# Out:
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-14d3f9a47da5> in <cell line: 0>()
#       5
#       6 n = int(input())
# ----> 7 print(fib(n))
#
# <ipython-input-25-14d3f9a47da5> in fib(n)
#       2   if n == 1 or n == 2:
#       3     return
# ----> 4   return fib(n-2) + fib(n-1)
#       5
#       6 n = int(input())
#
# <ipython-input-25-14d3f9a47da5> in fib(n)
#       2   if n == 1 or n == 2:
#       3     return
# ----> 4   return fib(n-2) + fib(n-1)
#       5
#       6 n = int(input())
#
# <ipython-input-25-14d3f9a47da5> in fib(n)
#       2   if n == 1 or n == 2:
#       3     return
# ----> 4   return fib(n-2) + fib(n-1)
#       5
#       6 n = int(input())
#
# <ipython-input-25-14d3f9a47da5> in fib(n)
#       2   if n == 1 or n == 2:
#       3     return
# ----> 4   return fib(n-2) + fib(n-1)
#       5
#       6 n = int(input())
#
# ...
